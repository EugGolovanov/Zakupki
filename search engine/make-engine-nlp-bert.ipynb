# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from pyjarowinkler import distance
import faiss

# %%
def get_model_tokenizer(hub_name: str):
    tokenizer = AutoTokenizer.from_pretrained(hub_name)
    model = AutoModel.from_pretrained(hub_name)
    return model, tokenizer

class BertCLS(nn.Module):
    def __init__(self, model, n_classes):
        super(BertCLS, self).__init__()
        self.model = model
        self.fc = nn.Linear(312, n_classes)
    
    def forward(self, batch):
        return self.fc(self.model(**batch).pooler_output)
    
def get_embeddings(bert_cls, tokenizer, text):
    tokens = tokenizer(text, padding=True,
                       max_length=300, truncation=True,
                       return_tensors='pt')
    tokens = tokens.to(bert_cls.model.device)
    return bert_cls.model(**tokens).pooler_output.detach().cpu().numpy()

def string_dist(str1, str2):
    return distance.get_jaro_distance(str1, str2,
                                      winkler=True,
                                      winkler_ajustment=True,
                                      scaling=0.2)

# %%
model, tokenizer = get_model_tokenizer("cointegrated/rubert-tiny2")
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny2 were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')

# %%
bert_cls = BertCLS(model, 1005)
bert_cls.load_state_dict(torch.load("./BertCLS_epoch_3_1000.pth", map_location=torch.device("cpu")))
bert_cls = bert_cls.to(device)

# %%
final_df = pd.read_feather("bert-tiny-1000-final-df.feather")
search_df = final_df[final_df.columns[312:]].reset_index(drop=True)

# %%
embeddings = final_df[final_df.columns[:312]].values.astype(np.float32)
embeddings = np.ascontiguousarray(embeddings)
faiss.normalize_L2(embeddings)

# %%
d = 312 # длина эмбеддинга
index = faiss.IndexFlatIP(d)
index.add(embeddings) # сами эмбеддинги, нампай массив shape = (n_samples, d)

# %%
text_query = "стул деревянный"
xq = get_embeddings(bert_cls, tokenizer, text_query)
faiss.normalize_L2(xq)

# %%
k = 100
D, I = index.search(xq, k) # xq shape = (1, d)

# %%
faiss_results = search_df.iloc[I[0]].reset_index(drop=True)
faiss_results["string_dist"] = faiss_results["product_name"].apply(lambda x: string_dist(x, text_query))
faiss_results
# Out:
#                                         product_name     price  \
# 0                                   стул ученический   2000.00
# 1                      стул ученический лабораторный   4251.57
# 2                                      стул изо хром   2000.00
# 3                                               стул   2055.00
# 4                                         стул тип 2   9740.89
# ..                                               ...       ...
# 95  Стул ученический, регулировка высоты (4-6 гр.р.)   1333.75
# 96                              стол манипуляционный   9441.89
# 97                               Стул нерегулируемый   3188.00
# 98                                      кресло тип 3  15946.66
# 99                                      кресло тип 3  48516.81
#
#    product_vat_rate product_msr product_characteristics    okpd2_code  \
# 0               20%       Штука                          32.99.59.000
# 1           Без НДС       Штука                          31.01.11.150
# 2                0%       Штука                          31.01.11.150
# 3           Без НДС       Штука                          32.99.59.000
# 4                0%       Штука                          31.09.99.211
# ..              ...         ...                     ...           ...
# 95          Без НДС       Штука                          31.01.11.150
# 96          Без НДС       Штука                          32.50.21.111
# 97          Без НДС       Штука                          31.09.12.121
# 98          Без НДС       Штука                          31.01.12.160
# 99               0%       Штука                          31.09.99.211
#
#                                            okpd2_name  \
# 0   Изделия различные прочие, не включенные в друг...
# 1   Мебель для сидения, преимущественно с металлич...
# 2   Мебель для сидения, преимущественно с металлич...
# 3   Изделия различные прочие, не включенные в друг...
# 4   Услуги по изготовлению мягкой мебели по индиви...
# ..                                                ...
# 95  Мебель для сидения, преимущественно с металлич...
# 96                        Инструменты терапевтические
# 97                    Кровати деревянные для взрослых
# 98  Мебель для сидения, преимущественно с деревянн...
# 99  Услуги по изготовлению мягкой мебели по индиви...
#
#                                  inn country_code okpd2_value  \
# 0   8764d748838ad7fc3a975f3757167aec          643          32
# 1   247ca9307cf09e6b9e3bb8b1c9212e83          643          31
# 2   86875838b24b114a9289fc313e90788d          643          31
# 3   4bdab417f1773e8e76887a99c27cde5a          643          32
# 4   e3674a861c1e906db077407701580cf2          643          31
# ..                               ...          ...         ...
# 95  ba7d6516f94e3fae34f89701d8f11fde          643          31
# 96  6bdb620dfd87a464cf19992889a98a97          643          32
# 97  887701edda2e879deed0ed618185b9d3          643          31
# 98  441fbd989720975cf5d6b0a7a098badc          643          31
# 99  e3674a861c1e906db077407701580cf2          643          31
#
#                                                  text  string_dist
# 0                              стул ученический [SEP]         0.94
# 1                 стул ученический лабораторный [SEP]         0.92
# 2                                 стул изо хром [SEP]         0.92
# 3                                          стул [SEP]         0.95
# 4                                    стул тип 2 [SEP]         0.92
# ..                                                ...          ...
# 95  Стул ученический, регулировка высоты (4-6 гр.р...         0.56
# 96                         стол манипуляционный [SEP]         0.79
# 97                          Стул нерегулируемый [SEP]         0.71
# 98                                 кресло тип 3 [SEP]         0.47
# 99                                 кресло тип 3 [SEP]         0.47
#
# [100 rows x 12 columns]

# %%
faiss_results.sort_values(by="string_dist", ascending=False).head(10)
# Out:
#                      product_name     price product_vat_rate product_msr  \
# 8                    стул детский   2500.00              20%       Штука
# 6                    стул офисный  10700.00          Без НДС       Штука
# 3                            стул   2055.00          Без НДС       Штука
# 84     стул на деревянном каркасе  21505.00              20%       Штука
# 11               стул медицинский   8018.00               0%       Штука
# 0                стул ученический   2000.00              20%       Штука
# 10        стул ученический (тип2)   3533.33          Без НДС       Штука
# 13        стул ученический (тип6)   2773.33          Без НДС       Штука
# 5                      стул тип 1  22821.76               0%       Штука
# 1   стул ученический лабораторный   4251.57          Без НДС       Штука
#
#    product_characteristics    okpd2_code  \
# 8                           31.09.13.190
# 6                           31.01.11.150
# 3                           32.99.59.000
# 84                          31.01.12.160
# 11                          32.50.30.119
# 0                           32.99.59.000
# 10                          31.01.11.150
# 13                          31.01.11.150
# 5                           31.09.99.211
# 1                           31.01.11.150
#
#                                            okpd2_name  \
# 8   Мебель деревянная прочая, не включенная в друг...
# 6   Мебель для сидения, преимущественно с металлич...
# 3   Изделия различные прочие, не включенные в друг...
# 84  Мебель для сидения, преимущественно с деревянн...
# 11  Мебель медицинская прочая, включая хирургическ...
# 0   Изделия различные прочие, не включенные в друг...
# 10  Мебель для сидения, преимущественно с металлич...
# 13  Мебель для сидения, преимущественно с металлич...
# 5   Услуги по изготовлению мягкой мебели по индиви...
# 1   Мебель для сидения, преимущественно с металлич...
#
#                                  inn country_code okpd2_value  \
# 8   260784b5cc1c089d1409e90ddefa8a3d          643          31
# 6   165dc33671d7778cb9dd50238a7d7e5e          643          31
# 3   4bdab417f1773e8e76887a99c27cde5a          643          32
# 84  72d10f8a4fcf25bcfa9159c867a02a7d          643          31
# 11  926dc3e32feb99196cb926959af17dbd          643          32
# 0   8764d748838ad7fc3a975f3757167aec          643          32
# 10  f0ab568683992c6d0724646692ed9ccd          643          31
# 13  f0ab568683992c6d0724646692ed9ccd          643          31
# 5   e3674a861c1e906db077407701580cf2          643          31
# 1   247ca9307cf09e6b9e3bb8b1c9212e83          643          31
#
#                                    text  string_dist
# 8                    стул детский [SEP]         0.95
# 6                    стул офисный [SEP]         0.95
# 3                            стул [SEP]         0.95
# 84     стул на деревянном каркасе [SEP]         0.94
# 11               стул медицинский [SEP]         0.94
# 0                стул ученический [SEP]         0.94
# 10        стул ученический (тип2) [SEP]         0.93
# 13        стул ученический (тип6) [SEP]         0.93
# 5                      стул тип 1 [SEP]         0.92
# 1   стул ученический лабораторный [SEP]         0.92
